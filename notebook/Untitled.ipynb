# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("92596/00010.jpg")
im = np.array(im)
im.shape
# Out:
# (100, 132, 3)

# %%
plt.imshow(im)

# %%
box_list = np.load("bbox_92596/00010.npy")
plt.imshow(img.crop((0, min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1]))))

# %%
box_list
# Out:
# array([[ -7.15697145,  30.75389481],
#        [ 65.04995775,   3.07637405],
#        [ 92.72750521,  75.28332138],
#        [ 20.520576  , 102.96084213]])

# %%
box_list = np.int8(np.round(box_list))
plt.imshow(img.crop((0, min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1]))))

# %%
import cv2

crop_img = im[y:y+h, x:x+w]

# %%
crop_img.shape
# Out:
# (97, 0, 3)

# %%
plt.imshow(img.crop((0, min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1]))))

# %%
box_list[0,0] = 0
K = img.crop((min(box_list[:,0]), min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1])))
plt.imshow(K)
plt.axvline(x=max(box_list[:,0]), color = "red")
plt.axhline(y=max(box_list[:,1]), color = "red")
# plt.axvline(x=2.20589566)

# %%
x, y, w, h = (min(box_list[:,0]), min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1]))

# %%
np.max(im)
# X = np.array(K)
# X[..., 0].shape
# Out:
# 168

# %%
(min(box_list[:,0]), min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1]))
# Out:
# (-7.1569714546203596, 3.076374053955089, 92.72750520706175, 102.96084213256836)

# %%
bg = Image.new('RGB', (min(box_list[:,0]), min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1])))
bg.paste(img, (-x1, -y1))
plt.imshow(img.crop())

# %%
# %run non_max_suppression_fast.py
# %run palm_detector.py
   
palm_model_path = "./models/palm_detection_without_custom_op.tflite"
anchors_path = "./data/anchors.csv"


input_path = "F:/20bn-jester/20bn-jester-v1/"
output_path = "F:/20bn-jester/bbox_output/"



detector = PalmDetector(palm_model_path, anchors_path)

path_im = "92596/00020.jpg"
img = Image.open(path_im)
img = np.array(img)
import matplotlib.pyplot as plt
#plt.imshow(img)

box_list = detector(img)
print(box_list)


img = Image.open(path_im)
img2 = img.crop((-1*min(box_list[:,0]), -1*min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1])))
plt.imshow(img2)
plt.show()
# Out:
# [[ -4.136271    16.23740196]
#  [ 76.66905451  -7.58301735]
#  [100.48947382  73.22229958]
#  [ 19.68414831  97.04271889]]
# F:\20bn-jester\Gesture-Reco\notebook\palm_detector.py:98: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x) )

# %%
np.array(img2).shape
# Out:
# (105, 104, 3)

# %%
-1*min(box_list[:,0]), -1*min(box_list[:,1]), max(box_list[:,0]), max(box_list[:,1])
# Out:
# (4.136270999908447, 7.583017349243171, 100.48947381973267, 97.0427188873291)
